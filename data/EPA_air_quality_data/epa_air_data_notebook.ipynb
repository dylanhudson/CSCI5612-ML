# %% [markdown]
# # EPA Air Quality Data Cleaning / EDA / Viz

# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas

# %%
#read in data 
air_data = pd.read_csv('../../../raw_data_CSCI5612-ML/annual_conc_by_monitor_2013.csv')
air_data.head()
# Out:
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0           1            3        10           44201    1  30.497478
# 1           1            3        10           44201    1  30.497478
# 2           1            3        10           44201    1  30.497478
# 3           1            3        10           44201    1  30.497478
# 4           1            3        10           68101    1  30.497478
#
#    Longitude  Datum        Parameter Name          Sample Duration  ...  \
# 0 -87.880258  NAD83                 Ozone                   1 HOUR  ...
# 1 -87.880258  NAD83                 Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 2 -87.880258  NAD83                 Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 3 -87.880258  NAD83                 Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 4 -87.880258  NAD83  Sample Flow Rate- CV                  24 HOUR  ...
#
#   75th Percentile 50th Percentile 10th Percentile    Local Site Name  \
# 0           0.052           0.045           0.027  FAIRHOPE, Alabama
# 1           0.048           0.040           0.023  FAIRHOPE, Alabama
# 2           0.048           0.040           0.023  FAIRHOPE, Alabama
# 3           0.047           0.039           0.023  FAIRHOPE, Alabama
# 4           0.000           0.000           0.000  FAIRHOPE, Alabama
#
#                                              Address State Name  County Name  \
# 0  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...    Alabama      Baldwin
# 1  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...    Alabama      Baldwin
# 2  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...    Alabama      Baldwin
# 3  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...    Alabama      Baldwin
# 4  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...    Alabama      Baldwin
#
#    City Name                  CBSA Name  Date of Last Change
# 0   Fairhope  Daphne-Fairhope-Foley, AL           2024-06-01
# 1   Fairhope  Daphne-Fairhope-Foley, AL           2024-06-01
# 2   Fairhope  Daphne-Fairhope-Foley, AL           2024-06-01
# 3   Fairhope  Daphne-Fairhope-Foley, AL           2024-06-01
# 4   Fairhope  Daphne-Fairhope-Foley, AL           2020-05-21
#
# [5 rows x 55 columns]

# %%
air_data.columns
# Out:
# Index(['State Code', 'County Code', 'Site Num', 'Parameter Code', 'POC',
#        'Latitude', 'Longitude', 'Datum', 'Parameter Name', 'Sample Duration',
#        'Pollutant Standard', 'Metric Used', 'Method Name', 'Year',
#        'Units of Measure', 'Event Type', 'Observation Count',
#        'Observation Percent', 'Completeness Indicator', 'Valid Day Count',
#        'Required Day Count', 'Exceptional Data Count', 'Null Data Count',
#        'Primary Exceedance Count', 'Secondary Exceedance Count',
#        'Certification Indicator', 'Num Obs Below MDL', 'Arithmetic Mean',
#        'Arithmetic Standard Dev', '1st Max Value', '1st Max DateTime',
#        '2nd Max Value', '2nd Max DateTime', '3rd Max Value',
#        '3rd Max DateTime', '4th Max Value', '4th Max DateTime',
#        '1st Max Non Overlapping Value', '1st NO Max DateTime',
#        '2nd Max Non Overlapping Value', '2nd NO Max DateTime',
#        '99th Percentile', '98th Percentile', '95th Percentile',
#        '90th Percentile', '75th Percentile', '50th Percentile',
#        '10th Percentile', 'Local Site Name', 'Address', 'State Name',
#        'County Name', 'City Name', 'CBSA Name', 'Date of Last Change'],
#       dtype='object')

# %%
#grabbed this code from my 500_cities_data analysis, just needs minor mods
def load_fips_lookup(file_path):
    # ref for lookup csv 
    #"State Name","County Name","City Name","State Code","State FIPS Code","County Code","StCnty FIPS Code","City Code","StCntyCity FIPS Code"
   # "ALABAMA","BALDWIN","ELBERTA","AL","01","C003","01003","1011","010031011"
   #all the codes must read in as strings, not floats, so we can preserve leading zeros, and trailing zeros
    fips_df = pd.read_csv(file_path, dtype=str)
    fips_dict = {}
    for _, row in fips_df.iterrows():
        state = str(row['State Name']).replace(" ", "").upper()
        county = str(row['County Name']).replace(" ", "").upper()
        fips_code = row['StCnty FIPS Code']
        fips_dict[(county, state)] = fips_code
        #print(f"Loaded FIPS code for county: {county}, state: {state} -> fips: {fips_code}")
    #print(fips_dict)
    return fips_dict

#fips dict format : {('AUTAUGA', 'AL'): '01001', ('BALDWIN', 'AL'): 
def lookup_fips(fips_dict, row):
    county = row['County Name']
    county = county.replace(" ", "").upper()
    state = row['State Name']
    state = state.replace(" ", "").upper()  
    code = fips_dict.get((county, state), None)
    #for debug
    #print(f"Looking up fips for county: {county}, state: {state} -> fips: {code}")
    return code

# %%
fips_file = "State_County_and_City_FIPS_Reference_Table_20260601.txt"
fips_dict = load_fips_lookup(fips_file)
air_data['FIPS'] = air_data.apply(lambda row: lookup_fips(fips_dict, row), axis=1)
air_data.head()
# Out:
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0           1            3        10           44201    1  30.497478
# 1           1            3        10           44201    1  30.497478
# 2           1            3        10           44201    1  30.497478
# 3           1            3        10           44201    1  30.497478
# 4           1            3        10           68101    1  30.497478
#
#    Longitude  Datum        Parameter Name          Sample Duration  ...  \
# 0 -87.880258  NAD83                 Ozone                   1 HOUR  ...
# 1 -87.880258  NAD83                 Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 2 -87.880258  NAD83                 Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 3 -87.880258  NAD83                 Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 4 -87.880258  NAD83  Sample Flow Rate- CV                  24 HOUR  ...
#
#   50th Percentile 10th Percentile    Local Site Name  \
# 0           0.045           0.027  FAIRHOPE, Alabama
# 1           0.040           0.023  FAIRHOPE, Alabama
# 2           0.040           0.023  FAIRHOPE, Alabama
# 3           0.039           0.023  FAIRHOPE, Alabama
# 4           0.000           0.000  FAIRHOPE, Alabama
#
#                                              Address State Name County Name  \
# 0  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...    Alabama     Baldwin
# 1  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...    Alabama     Baldwin
# 2  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...    Alabama     Baldwin
# 3  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...    Alabama     Baldwin
# 4  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...    Alabama     Baldwin
#
#    City Name                  CBSA Name Date of Last Change   FIPS
# 0   Fairhope  Daphne-Fairhope-Foley, AL          2024-06-01  01003
# 1   Fairhope  Daphne-Fairhope-Foley, AL          2024-06-01  01003
# 2   Fairhope  Daphne-Fairhope-Foley, AL          2024-06-01  01003
# 3   Fairhope  Daphne-Fairhope-Foley, AL          2024-06-01  01003
# 4   Fairhope  Daphne-Fairhope-Foley, AL          2020-05-21  01003
#
# [5 rows x 56 columns]

# %%
#how many NaNs per column?
print(air_data.isna().sum())
print(air_data.shape)

#which FIPS codes are missing?
missing_fips = air_data[air_data['FIPS'].isna()]
#print(missing_fips[['County Name', 'State Name']])
# Out:
# State Code                           0
# County Code                          0
# Site Num                             0
# Parameter Code                       0
# POC                                  0
# Latitude                             0
# Longitude                            0
# Datum                                0
# Parameter Name                       0
# Sample Duration                      0
# Pollutant Standard               64449
# Metric Used                          0
# Method Name                       9883
# Year                                 0
# Units of Measure                     0
# Event Type                           0
# Observation Count                    0
# Observation Percent                  0
# Completeness Indicator               0
# Valid Day Count                      0
# Required Day Count                   0
# Exceptional Data Count               0
# Null Data Count                      0
# Primary Exceedance Count         70869
# Secondary Exceedance Count       71793
# Certification Indicator              0
# Num Obs Below MDL                    0
# Arithmetic Mean                     19
# Arithmetic Standard Dev             19
# 1st Max Value                        3
# 1st Max DateTime                     3
# 2nd Max Value                      127
# 2nd Max DateTime                   127
# 3rd Max Value                      184
# 3rd Max DateTime                   184
# 4th Max Value                      482
# 4th Max DateTime                   482
# 1st Max Non Overlapping Value    86369
# 1st NO Max DateTime              86369
# 2nd Max Non Overlapping Value    86369
# 2nd NO Max DateTime              86369
# 99th Percentile                     18
# 98th Percentile                     18
# 95th Percentile                     18
# 90th Percentile                     18
# 75th Percentile                     35
# 50th Percentile                     40
# 10th Percentile                    132
# Local Site Name                   2688
# Address                             46
# State Name                           0
# County Name                          0
# City Name                        17765
# CBSA Name                         8363
# Date of Last Change                  0
# FIPS                              2625
# dtype: int64
# (86699, 56)

# %%
#drop alot of these columns, especially most the the ones with many NaNs, and the ones we won't use for our analysis
columns_to_drop = ['Site Num', 'Latitude', 'Longitude', 'Datum', 'Date of Last Change', 'Null Data Count', 'Num Obs Below MDL', 'Primary Exceedance Count', 'Secondary Exceedance Count',
                   'Required Day Count', 'Valid Day Count', 'Local Site Name', 'CBSA Name', '1st Max Value', '1st Max DateTime', '2nd Max Value', '2nd Max DateTime',
                   '3rd Max Value', '3rd Max DateTime', '4th Max Value', '4th Max DateTime', '1st Max Non Overlapping Value', '1st Max DateTime', 
                   '2nd Max Non Overlapping Value', '2nd Max DateTime', 'Pollutant Standard', 'Method Name', '1st NO Max DateTime', '2nd NO Max DateTime', 'City Name']
air_data = air_data.drop(columns=columns_to_drop)
air_data.head()
# Out:
#    State Code  County Code  Parameter Code  POC        Parameter Name  \
# 0           1            3           44201    1                 Ozone
# 1           1            3           44201    1                 Ozone
# 2           1            3           44201    1                 Ozone
# 3           1            3           44201    1                 Ozone
# 4           1            3           68101    1  Sample Flow Rate- CV
#
#            Sample Duration                                        Metric Used  \
# 0                   1 HOUR  Daily maxima of observed hourly values (betwee...
# 1  8-HR RUN AVG BEGIN HOUR  Daily maximum of 8 hour running average of obs...
# 2  8-HR RUN AVG BEGIN HOUR  Daily maximum of 8 hour running average of obs...
# 3  8-HR RUN AVG BEGIN HOUR            Daily maximum of 8-hour running average
# 4                  24 HOUR                                    Observed Values
#
#    Year   Units of Measure Event Type  ...  98th Percentile  95th Percentile  \
# 0  2013  Parts per million  No Events  ...            0.068            0.064
# 1  2013  Parts per million  No Events  ...            0.062            0.059
# 2  2013  Parts per million  No Events  ...            0.062            0.059
# 3  2013  Parts per million  No Events  ...            0.062            0.059
# 4  2013            Percent  No Events  ...            0.200            0.100
#
#   90th Percentile  75th Percentile 50th Percentile  10th Percentile  \
# 0           0.061            0.052           0.045            0.027
# 1           0.056            0.048           0.040            0.023
# 2           0.056            0.048           0.040            0.023
# 3           0.055            0.047           0.039            0.023
# 4           0.100            0.000           0.000            0.000
#
#                                              Address  State Name  County Name  \
# 0  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...     Alabama      Baldwin
# 1  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...     Alabama      Baldwin
# 2  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...     Alabama      Baldwin
# 3  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...     Alabama      Baldwin
# 4  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...     Alabama      Baldwin
#
#     FIPS
# 0  01003
# 1  01003
# 2  01003
# 3  01003
# 4  01003
#
# [5 rows x 28 columns]

# %%
#recheck for NaNs 
print(air_data.isna().sum())
print(air_data.shape)
# Out:
# State Code                    0
# County Code                   0
# Parameter Code                0
# POC                           0
# Parameter Name                0
# Sample Duration               0
# Metric Used                   0
# Year                          0
# Units of Measure              0
# Event Type                    0
# Observation Count             0
# Observation Percent           0
# Completeness Indicator        0
# Exceptional Data Count        0
# Certification Indicator       0
# Arithmetic Mean              19
# Arithmetic Standard Dev      19
# 99th Percentile              18
# 98th Percentile              18
# 95th Percentile              18
# 90th Percentile              18
# 75th Percentile              35
# 50th Percentile              40
# 10th Percentile             132
# Address                      46
# State Name                    0
# County Name                   0
# FIPS                       2625
# dtype: int64
# (86699, 28)

# %%
#okay that looks much better, we can just drop NaN rows now, and should have plenty left
air_data = air_data.dropna()
print(air_data.isna().sum())
print(air_data.shape)
# Out:
# State Code                 0
# County Code                0
# Parameter Code             0
# POC                        0
# Parameter Name             0
# Sample Duration            0
# Metric Used                0
# Year                       0
# Units of Measure           0
# Event Type                 0
# Observation Count          0
# Observation Percent        0
# Completeness Indicator     0
# Exceptional Data Count     0
# Certification Indicator    0
# Arithmetic Mean            0
# Arithmetic Standard Dev    0
# 99th Percentile            0
# 98th Percentile            0
# 95th Percentile            0
# 90th Percentile            0
# 75th Percentile            0
# 50th Percentile            0
# 10th Percentile            0
# Address                    0
# State Name                 0
# County Name                0
# FIPS                       0
# dtype: int64
# (83895, 28)

# %%
#visualize data 
#what are the top parameters we have metrics for?
# means by 
pollutant_means = air_data.groupby('Parameter Name')['Arithmetic Mean'].mean().sort_values(ascending=False).head(20)
plt.figure(figsize=(10, 8))
pollutant_means.plot(kind='bar')
plt.title('Average Pollutant Concentration by Parameter Name')
plt.xlabel('Parameter Name')
plt.ylabel('Average Concentration')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Maybe we can use dimensionality reduction to see which of these are really going to be interesting to look at...

# %%
#export data to csv for later use
air_data.to_csv('cleaned_air_quality_data.csv', index=False)
