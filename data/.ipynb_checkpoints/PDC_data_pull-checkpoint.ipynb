# %% [markdown]
# # Pulling data from the Proteomic Data Commons (PDC) API

# %% [markdown]
# First, library imports and setting the API endpoint in a global var:

# %%
import requests
import json
import pandas as pd
PDC_GRAPHQL_URL = 'https://pdc.cancer.gov/graphql'

# %% [markdown]
# API Docs references:
# https://pdc.cancer.gov/pdc-docs/api-documentation
# https://pdc.cancer.gov/pdc/publicapi-documentation/#!/Case/allCases
# https://proteomic.datacommons.cancer.gov/API_documentation/PDC_clustergram.html
#
# No authentication is required and  "all requests must be HTTP POST requests with application/json encoded bodies".
# A "case" appears to refer to a single patient, which sounds like the natural record unit.  Cases are part of "Studies" on particular disease types.
# In the protein data, an 'aliquot' is an analyzed part of a sample from a given patient, so some cases will have corresponding aliquots; a mapping for the IDs
# is provided via the API.
# Most helpful sections:
# Exposures -> per-case expoures to known carcinogens (smoking, etc)
# Demographics  -> per case demographic information (sex, age, etc)
# Protein expression data -> results of analyzing tissue samples.

# %%
#querying to see all the studies available...this query string is provided in the docs, so we should be able to use it and determine the result schema. 
query = '{ studyCatalog { pdc_study_id versions { study_id study_submitter_id submitter_id_name study_shortname study_version is_latest_version } } }'
response = requests.post(PDC_GRAPHQL_URL, json={'query': query}, headers={'Content-Type': 'application/json'})
data=response.json()
#Catalog response is huge, so abbreviate to confirm successfuyl call
print(str(data)[1:500])
# Out:
# 'data': {'studyCatalog': [{'pdc_study_id': 'PDC000109', 'versions': [{'study_id': 'bb67ec40-57b8-11e8-b07a-00a098d917f8', 'study_submitter_id': 'Prospective COAD Proteome S037-1', 'submitter_id_name': 'Prospective Colon VU Proteome', 'study_shortname': 'Prospective COAD Proteome S037-1', 'study_version': '1', 'is_latest_version': 'yes'}]}, {'pdc_study_id': 'PDC000110', 'versions': [{'study_id': '6338aad7-851b-4eea-ba90-ba50237cb875', 'study_submitter_id': 'Prospective Ovarian JHU Proteome v2',

# %%
formatted_result = json.dumps(data, indent=2)
#prints out all 227 studies; this is really long
#print(formatted_result)

#print 1st result only to confirm the schema
print(formatted_result[1:500])

#need to select studies that are of relevant types, i.e. relate to other data sources (especially the transcriptomics data, in case there's any overlap multi-omics analysis possible).
search_terms = ["colon", "rect", "breast", "ucec", "uter", "pancrea", "pda"]

#search the "versions" field for each study for the relevant cancer types, and print the pdc_study_id of those that match.
print("relevant studies:")
for study in data['data']['studyCatalog']:
    if any(term in str(study['versions']).lower() for term in search_terms) and "proteome" in str(study['versions']).lower():
        print(study['pdc_study_id'], study['versions'][0]['study_shortname'], study['versions'][0]['study_version'], study['versions'][0]['study_id'])
# Out:
#   "data": {
#     "studyCatalog": [
#       {
#         "pdc_study_id": "PDC000109",
#         "versions": [
#           {
#             "study_id": "bb67ec40-57b8-11e8-b07a-00a098d917f8",
#             "study_submitter_id": "Prospective COAD Proteome S037-1",
#             "submitter_id_name": "Prospective Colon VU Proteome",
#             "study_shortname": "Prospective COAD Proteome S037-1",
#             "study_version": "1",
#             "is_latest_version": "yes"
#           }
#         ]
#       },
#       {
#
# relevant studies:
# PDC000109 Prospective COAD Proteome S037-1 1 bb67ec40-57b8-11e8-b07a-00a098d917f8
# PDC000111 TCGA COAD Proteome S016-1 1 b998098f-57b8-11e8-b07a-00a098d917f8
# PDC000116 Prospective COAD Proteome S037-2 1 bbc1441e-57b8-11e8-b07a-00a098d917f8
# PDC000117 Prospective COAD Phosphoproteome S037-3 1 bc23a4a1-57b8-11e8-b07a-00a098d917f8
# PDC000120 Prospective Breast BI Proteome 2 b91a0a02-f3a0-11ea-b1fd-0aad30af8a83
# PDC000121 Prospective Breast BI Phosphoproteome 2 b91a0e5f-f3a0-11ea-b1fd-0aad30af8a83
# PDC000123 UCEC Discovery - CompRef Phosphoproteome S043-2 1 de58a7ea-06ad-11ea-8c2e-0a7b46c3918d
# PDC000124 UCEC Discovery - CompRef Proteome S043-1 1 de58670a-06ad-11ea-8c2e-0a7b46c3918d
# PDC000125 UCEC Discovery - Proteome S043-1 1 c935c587-0cd1-11e9-a064-0a9c39d33490
# PDC000126 UCEC Discovery - Phosphoproteome S043-2 1 cb7220f5-0cd1-11e9-a064-0a9c39d33490
# PDC000173 TCGA BRCA Proteome S015-1 1 b8da9eeb-57b8-11e8-b07a-00a098d917f8
# PDC000174 TCGA BRCA Phosphoproteome S015-2 1 b93bb1e9-57b8-11e8-b07a-00a098d917f8
# PDC000242 Prospective Breast BI - CompRef Proteome 1 b91a0c3f-f3a0-11ea-b1fd-0aad30af8a83
# PDC000244 Prospective Breast BI - CompRef Phosphoproteome 1 b91a1077-f3a0-11ea-b1fd-0aad30af8a83
# PDC000248 KU PDAC Discovery Study - Global proteome 1 4f354c22-0421-11eb-bc0e-0aad30af8a83
# PDC000249 KU PDAC Discovery Study - Phosphoproteome 1 651d728a-f87b-4990-b534-d53a63b17c54
# PDC000270 CPTAC PDA Discovery Study - Proteome 1 1cf6e56a-02f4-4687-8f87-ab37b0f41960
# PDC000271 CPTAC PDA Discovery Study - Phosphoproteome 1 71f65605-162a-4b7b-b641-a696cb3eeebe
# PDC000272 CPTAC PDA Discovery Study - Intact Glycoproteome 1 fc4826f7-a79d-4b70-8e47-11e85adbbb7f
# PDC000278 VU Normal Colon Epithelium - Proteome 1 3ea1fbb1-0f05-447e-853e-639338442830
# PDC000289 TCGA Colorectal Cancer CompRef Samples - Proteome 1 5d019771-c39c-4dec-b2a9-f0aec54a796f
# PDC000290 TCGA Breast Cancer CompRef Samples - Proteome 1 57b07c60-c9e1-424f-bfd6-9262e06a77d8
# PDC000291 TCGA Breast Cancer CompRef Samples - Phosphoproteome 1 a2df3cc3-2c40-4da6-ac5a-ff016cce4bbd
# PDC000303 Therapeutic Targets in Breast Cancer Xenografts -  Proteome 1 f0f337b3-563b-4335-83d8-7e65146102a0
# PDC000304 Therapeutic Targets in Breast Cancer Xenografts -  Phosphoproteome 1 debd14db-1702-4bd2-b3cf-7349739f7c6b
# PDC000341 CPTAC PDA Discovery Study - DIA Proteome 1 35a494ec-87f3-41b5-8e4e-f712096440a0
# PDC000393 Sampling techniques for enrichment of PDAC - Proteome 1 26da108f-b554-4c81-8397-0aded036fe93
# PDC000439 CPTAC UCEC Confirmatory Study - Proteome 1 401b6a4e-e36e-4bd2-be2a-2926eaa44d88
# PDC000440 CPTAC UCEC Confirmatory Study - CompRef Proteome 1 6cae9b33-280a-4c68-aafd-34b655ec13e3
# PDC000441 CPTAC UCEC Confirmatory Study - Phosphoproteome 1 07a7b5aa-e984-480c-a339-a9399d7aa787
# PDC000442 CPTAC UCEC Confirmatory Study - CompRef Phosphoproteome 1 2f64929c-bab2-4d8c-a7e5-0164a9df7ec6
# PDC000445 CPTAC UCEC Confirmatory Study - Glycoproteome 1 105df196-25b0-469a-829d-bb905ed2498d
# PDC000504 CPTAC PDAC BioTExt - Proteome 1 eb6aae30-9b42-4fe1-b3ed-22b55d730dfa
# PDC000526 CPTAC PDAC Proteins in Serum - Proteome 1 3615b133-a0d2-44cf-8b47-9c0408b3599d
# PDC000527 CPTAC PDAC Proteins in Serum - Glycoproteome 1 59a4929d-f5fe-48ae-bd22-7bb6824408a5
# PDC000579 PTRC Triple-negative Breast Cancer Mitotic Vulnerability Study - Proteome 1 fb66c568-85ff-460d-a630-f727f4abcc49
# PDC000580 PTRC Triple-negative Breast Cancer Mitotic Vulnerability Study - Phosphoproteome 1 7724a091-3349-46df-8db4-3ba210867e41
# PDC000629 IPMN Study - CPTAC PDAC Proteome 1 f3ef583b-d567-4845-9890-a20ead439bde

# %% [markdown]
# No pancreatic cancer appeared in the initial search; looking through the API docs and studies manually, it appears "PDA" is 'pancreatic ductal adenocarcinoma', so "pda" can be added to  to the search parameters.

# %%
#dict with the chosen study IDs for easier readability
STUDY_IDS = {
    'colorectal': ['PDC000111', 'b998098f-57b8-11e8-b07a-00a098d917f8'],
    'breast': ['PDC000173', 'b8da9eeb-57b8-11e8-b07a-00a098d917f8'],
    'ucec': ['PDC000125', 'c935c587-0cd1-11e9-a064-0a9c39d33490'],
    'colorectal_pnnl': ['PDC000116', 'bbc1441e-57b8-11e8-b07a-00a098d917f8'],
    'colorectal_vu': ['PDC000109', 'bb67ec40-57b8-11e8-b07a-00a098d917f8' ],
    'pancreatic': ['PDC000270', '1cf6e56a-02f4-4687-8f87-ab37b0f41960']
}

# %% [markdown]
# Now, the proteome, demographic, and exposure data must be queried for each study.

# %%
#helper function to wrap further API calls
def pdc_graphql_query(query):
    response = requests.post(
        PDC_GRAPHQL_URL,
        json={'query': query},
        headers={'Content-Type': 'application/json'}
    )
    data = response.json()
    if 'errors' in data:
        print("API error:", data['errors'])
        return None
    return data

# %%
def get_demographics(study_ids=STUDY_IDS, limit=1000):
    #initialize df list to hold all the results for each study; each study will have a df of cases, then we'll concat that
    all_dfs = []

    #for each study ID, get the demographics for all cases, and format in a df
    for cancer_type, pdc_study_id in study_ids.items():
        print(f"pulling demographics: {cancer_type} ({pdc_study_id[1]})...")

        # api ref: https://proteomic.datacommons.cancer.gov/pdc/publicapi-documentation/#!/Case/paginatedCaseDemographicsPerStudy
        query = '''
        {paginatedCaseDemographicsPerStudy (study_id: "%s" offset: 0 limit: %d) { total caseDemographicsPerStudy { case_id case_submitter_id disease_type primary_site demographics { demographic_id ethnicity gender demographic_submitter_id race cause_of_death days_to_birth days_to_death vital_status year_of_birth year_of_death age_at_index premature_at_birth weeks_gestation_at_birth age_is_obfuscated cause_of_death_source occupation_duration_years country_of_residence_at_enrollment} } pagination { count sort from page total pages size } }}
        ''' % (pdc_study_id[1], limit)

        data = pdc_graphql_query(query)
        if data is None:
            continue

        #need this parsed into a dataframe with each case as a row
        # can form rows by parsing the responses into a list of dicts, and then using Pandas to convert the resulting dict to a DataFrame
        cases = data['data']['paginatedCaseDemographicsPerStudy']['caseDemographicsPerStudy']
        rows = []
        for case in cases:
            row = {
                'case_id': case['case_id'],
                'case_submitter_id': case['case_submitter_id'],
                'disease_type': case['disease_type'],
                'primary_site': case['primary_site'],
                'pdc_study_id': pdc_study_id,
                'cancer_type': cancer_type
            }
            if case['demographics']:
                demo = case['demographics'][0]
                row.update({
                    'ethnicity': demo['ethnicity'],
                    'gender': demo['gender'],
                    'race':  demo['race'],
                    'vital_status': demo['vital_status'],
                    'days_to_birth': demo['days_to_birth'],
                    'days_to_death': demo['days_to_death']
                }  )
            rows.append(row)

        case_df = pd.DataFrame(rows)
        all_dfs.append(case_df)
        print(f"pulled {len(case_df)} cases")
    if not all_dfs:
        return None
    combined_dfs = pd.concat(all_dfs, ignore_index=True)
    print(f"total cases with demographic info puled: {len(combined_dfs)}")
    return combined_dfs

# %%
demographic_dfs = get_demographics()
#verify result looks good and save to csv for later joining with expsoure and protein data
if demographic_dfs is not None:
    print(demographic_dfs.head())
    demographic_dfs.to_csv('pdc_demographics.csv', index=False)
# Out:
# pulling demographics: colorectal (b998098f-57b8-11e8-b07a-00a098d917f8)...
# pulled 90 cases
# pulling demographics: breast (b8da9eeb-57b8-11e8-b07a-00a098d917f8)...
# pulled 109 cases
# pulling demographics: ucec (c935c587-0cd1-11e9-a064-0a9c39d33490)...
# pulled 123 cases
# pulling demographics: colorectal_pnnl (bbc1441e-57b8-11e8-b07a-00a098d917f8)...
# pulled 102 cases
# pulling demographics: colorectal_vu (bb67ec40-57b8-11e8-b07a-00a098d917f8)...
# pulled 100 cases
# pulling demographics: pancreatic (1cf6e56a-02f4-4687-8f87-ab37b0f41960)...
# pulled 166 cases
# total cases with demographic info puled: 690
#                                 case_id case_submitter_id  \
# 0  2dfc05ef-63d8-11e8-bcf1-0a2705229b82      TCGA-A6-3807
# 1  2f35a510-63d8-11e8-bcf1-0a2705229b82      TCGA-A6-3808
# 2  3073d082-63d8-11e8-bcf1-0a2705229b82      TCGA-A6-3810
# 3  40f43066-63d8-11e8-bcf1-0a2705229b82      TCGA-AA-3518
# 4  423218ed-63d8-11e8-bcf1-0a2705229b82      TCGA-AA-3525
#
#            disease_type primary_site  \
# 0  Colon Adenocarcinoma        Colon
# 1  Colon Adenocarcinoma        Colon
# 2  Colon Adenocarcinoma        Colon
# 3  Colon Adenocarcinoma        Colon
# 4  Colon Adenocarcinoma        Colon
#
#                                         pdc_study_id cancer_type  \
# 0  [PDC000111, b998098f-57b8-11e8-b07a-00a098d917f8]  colorectal
# 1  [PDC000111, b998098f-57b8-11e8-b07a-00a098d917f8]  colorectal
# 2  [PDC000111, b998098f-57b8-11e8-b07a-00a098d917f8]  colorectal
# 3  [PDC000111, b998098f-57b8-11e8-b07a-00a098d917f8]  colorectal
# 4  [PDC000111, b998098f-57b8-11e8-b07a-00a098d917f8]  colorectal
#
#                 ethnicity  gender          race vital_status days_to_birth  \
# 0  not hispanic or latino  female         white        Alive        -19624
# 1  not hispanic or latino    male         white        Alive        -26666
# 2  not hispanic or latino    male         white        Alive        -22999
# 3            not reported  female  not reported        Alive        -29769
# 4            not reported    male  not reported        Alive        -32871
#
#   days_to_death
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None

# %%
#similar paradigm for exposures
def get_exposures(study_ids=STUDY_IDS, limit=1000):
    all_dfs = []
    for cancer_type, pdc_study_id in study_ids.items():
        print(f"Pulling exposures: {cancer_type} ({pdc_study_id[0]})...")
        query = ''' { paginatedCaseExposuresPerStudy(pdc_study_id: "%s" offset: 0 limit: %d acceptDUA: true ) { total caseExposuresPerStudy {case_id case_submitter_id exposures { tobacco_smoking_status alcohol_history years_smoked pack_years_smoked }}}}
        ''' % (pdc_study_id[0], limit)

        data = pdc_graphql_query(query)
        if data is None:
            continue
        cases = data['data']['paginatedCaseExposuresPerStudy']['caseExposuresPerStudy']
        rows = []
        for case in cases:
            row = {
                'case_id': case['case_id'],
                'case_submitter_id': case['case_submitter_id'],
                'pdc_study_id': pdc_study_id[1],
                'cancer_type': cancer_type  }
            if case['exposures']:
                exp = case['exposures'][0]
                row.update({
                      'tobacco_smoking_status': exp['tobacco_smoking_status'],
                       'alcohol_history': exp['alcohol_history'],
                      'years_smoked': exp['years_smoked'],
                      'pack_years_smoked': exp['pack_years_smoked'],
})
            rows.append(row)
        df = pd.DataFrame(rows)
        all_dfs.append(df)
        print(f"got {len(df)} cases")

    if not all_dfs:
        return None
    combined_df = pd.concat(all_dfs, ignore_index=True)
    print(f"total cases from exposures data repo: {len(combined_df)}")
    return combined_df

# %%
exposure_dfs = get_exposures()
print(exposure_dfs.head())
exposure_dfs.to_csv('pdc_exposures.csv', index=False)
# Out:
# Pulling exposures: colorectal (PDC000111)...
#   Got 90 cases
# Pulling exposures: breast (PDC000173)...
#   Got 109 cases
# Pulling exposures: ucec (PDC000125)...
#   Got 123 cases
# Pulling exposures: colorectal_pnnl (PDC000116)...
#   Got 102 cases
# Pulling exposures: colorectal_vu (PDC000109)...
#   Got 100 cases
# Pulling exposures: pancreatic (PDC000270)...
#   Got 166 cases
# Total cases (exposures): 690
#                                 case_id case_submitter_id  \
# 0  2dfc05ef-63d8-11e8-bcf1-0a2705229b82      TCGA-A6-3807
# 1  2f35a510-63d8-11e8-bcf1-0a2705229b82      TCGA-A6-3808
# 2  3073d082-63d8-11e8-bcf1-0a2705229b82      TCGA-A6-3810
# 3  40f43066-63d8-11e8-bcf1-0a2705229b82      TCGA-AA-3518
# 4  423218ed-63d8-11e8-bcf1-0a2705229b82      TCGA-AA-3525
#
#                            pdc_study_id cancer_type tobacco_smoking_status  \
# 0  b998098f-57b8-11e8-b07a-00a098d917f8  colorectal                    NaN
# 1  b998098f-57b8-11e8-b07a-00a098d917f8  colorectal                    NaN
# 2  b998098f-57b8-11e8-b07a-00a098d917f8  colorectal                    NaN
# 3  b998098f-57b8-11e8-b07a-00a098d917f8  colorectal                    NaN
# 4  b998098f-57b8-11e8-b07a-00a098d917f8  colorectal                    NaN
#
#   alcohol_history years_smoked pack_years_smoked
# 0             NaN          NaN               NaN
# 1             NaN          NaN               NaN
# 2             NaN          NaN               NaN
# 3             NaN          NaN               NaN
# 4             NaN          NaN               NaN

# %%
def merge_demo_and_exposures_data(study_ids=STUDY_IDS):
    #read in the saved csvs
    demographics = pd.read_csv('pdc_demographics.csv')
    exposures = pd.read_csv('pdc_exposures.csv')

    # drop redundant columns 
    exposures = exposures.drop(columns=['pdc_study_id', 'cancer_type'])

    merged = demographics.merge(exposures, on=['case_id', 'case_submitter_id'], how='left')
    print(f"full dataset shape: {len(merged)} rows, {len(merged.columns)} columns")
    return merged

# %%
merged_data = merge_demo_and_exposures_data()
print(merged_data.head())
merged_data.to_csv('pdc_merged_data.csv', index=False)
# Out:
# full dataset shape: 884 rows, 16 columns
#                                 case_id case_submitter_id  \
# 0  2dfc05ef-63d8-11e8-bcf1-0a2705229b82      TCGA-A6-3807
# 1  2f35a510-63d8-11e8-bcf1-0a2705229b82      TCGA-A6-3808
# 2  3073d082-63d8-11e8-bcf1-0a2705229b82      TCGA-A6-3810
# 3  40f43066-63d8-11e8-bcf1-0a2705229b82      TCGA-AA-3518
# 4  423218ed-63d8-11e8-bcf1-0a2705229b82      TCGA-AA-3525
#
#            disease_type primary_site  \
# 0  Colon Adenocarcinoma        Colon
# 1  Colon Adenocarcinoma        Colon
# 2  Colon Adenocarcinoma        Colon
# 3  Colon Adenocarcinoma        Colon
# 4  Colon Adenocarcinoma        Colon
#
#                                         pdc_study_id cancer_type  \
# 0  ['PDC000111', 'b998098f-57b8-11e8-b07a-00a098d...  colorectal
# 1  ['PDC000111', 'b998098f-57b8-11e8-b07a-00a098d...  colorectal
# 2  ['PDC000111', 'b998098f-57b8-11e8-b07a-00a098d...  colorectal
# 3  ['PDC000111', 'b998098f-57b8-11e8-b07a-00a098d...  colorectal
# 4  ['PDC000111', 'b998098f-57b8-11e8-b07a-00a098d...  colorectal
#
#                 ethnicity  gender          race vital_status  days_to_birth  \
# 0  not hispanic or latino  female         white        Alive       -19624.0
# 1  not hispanic or latino    male         white        Alive       -26666.0
# 2  not hispanic or latino    male         white        Alive       -22999.0
# 3            not reported  female  not reported        Alive       -29769.0
# 4            not reported    male  not reported        Alive       -32871.0
#
#    days_to_death  tobacco_smoking_status alcohol_history  years_smoked  \
# 0            NaN                     NaN             NaN           NaN
# 1            NaN                     NaN             NaN           NaN
# 2            NaN                     NaN             NaN           NaN
# 3            NaN                     NaN             NaN           NaN
# 4            NaN                     NaN             NaN           NaN
#
#    pack_years_smoked
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
def get_protein_expression(study_ids=STUDY_IDS):
    #get protein expression matrix for each study.
    #returns a dict of {cancer_type: DataFrame} where each DataFrame is genes by samples (aliquots).
    results = {}
    for cancer_type, pdc_study_id in study_ids.items():
        print(f"pulling protein expression data for: {cancer_type} ({pdc_study_id[0]})...")
        query = ''' { quantDataMatrix( pdc_study_id: "%s" data_type: "log2_ratio" acceptDUA: true)} ''' % pdc_study_id[0]

        data = pdc_graphql_query(query)
        if data is None:
            continue
        prot_matrix = data['data']['quantDataMatrix']
        if not prot_matrix:
            print(f"no data returned for {pdc_study_id}")
            continue

        # first row is header: ["Gene/Aliquot", aliquot_id_1, aliquot_id_2, ...]
        #  first column is gene names, ie under 'Gene/Aliquot'
        protein_df = pd.DataFrame(prot_matrix[1:], columns=prot_matrix[0])
        protein_df = protein_df.set_index('Gene/Aliquot')

        # clean up aliquot IDs - pdc returns them as "study_id:aliquot_id" but we dont need the study id 
        protein_df.columns = [col.split(':')[1] if ':' in col else col for col in protein_df.columns]
        protein_df = protein_df.sort_index(axis=1)

          # save each cancer type separately in case these are really large, the protein matrices looked potentially huge in terms of the number of proteins
        results[cancer_type] = protein_df
        protein_df.to_csv(f'pdc_protein_expression_{cancer_type}.csv')
    return results

# %%
protein_data = get_protein_expression()

for cancer_type, df in protein_data.items():
    print(f"\n{cancer_type}:")
    print(f"genes: {df.shape[0]}, samples: {df.shape[1]}")
# Out:
# Pulling protein expression: colorectal (PDC000111)...
# API Error: Matrix data not found! pdc_study_id: PDC000111: log2_ratio
# Pulling protein expression: breast (PDC000173)...
# Pulling protein expression: ucec (PDC000125)...
# Pulling protein expression: colorectal_pnnl (PDC000116)...
# Pulling protein expression: colorectal_vu (PDC000109)...
# API Error: Matrix data not found! pdc_study_id: PDC000109: log2_ratio
# Pulling protein expression: pancreatic (PDC000270)...
#
# breast:
# genes: 10625, samples: 111
#
# ucec:
# genes: 10768, samples: 149
#
# colorectal_pnnl:
# genes: 7418, samples: 198
#
# pancreatic:
# genes: 10116, samples: 230

# %% [markdown]
# Looks like not all the studies had proteome data available; that's okay, we should have enough from those that do.
# The proteome/aliquot data needs to be attached to the case IDs so we can relate demographic and exposure info to the proteome.
# This means looking up the map data using the 'paginatedCasesSamplesAliquots' method.

# %%
def get_aliquot_mappings(study_ids=STUDY_IDS):
    all_mappings = []
    for cancer_type, pdc_study_id in study_ids.items():
        print(f"pulling aliquot mapping: {cancer_type} ({pdc_study_id[0]})...")
        query = '''
        {paginatedCasesSamplesAliquots( pdc_study_id: "%s" offset: 0 limit: 1000 acceptDUA: true ) { total casesSamplesAliquots { case_id case_submitter_id samples { sample_id sample_submitter_id sample_type aliquots { aliquot_id aliquot_submitter_id}}}}}
        ''' % pdc_study_id[0]

        data = pdc_graphql_query(query)
        if data is None:
            continue
        cases = data['data']['paginatedCasesSamplesAliquots']['casesSamplesAliquots']
        for case in cases:
            for sample in case.get('samples', []):
                for aliquot in sample.get('aliquots', []):
                    all_mappings.append({
                        'cancer_type': cancer_type,
                        'pdc_study_id': pdc_study_id,
                        'case_id':  case['case_id'],
                        'case_submitter_id': case['case_submitter_id'],
                        'sample_id': sample['sample_id'],
                        'sample_type': sample['sample_type'],
                        'aliquot_id':  aliquot['aliquot_id'],
                        'aliquot_submitter_id': aliquot['aliquot_submitter_id']
                    })
    mapping_df = pd.DataFrame(all_mappings)
    print(f" aliquot mappings: {len(mapping_df)}")
    print(mapping_df.head(10))
    mapping_df.to_csv('pdc_aliquot_mapping.csv', index=False)
    return mapping_df

# %%
mapping_data = get_aliquot_mappings(study_ids=STUDY_IDS)
print(mapping_data.head())
mapping_data.to_csv('pdc_aliquot_mapping.csv', index=False)
# Out:
# pulling aliquot mapping: colorectal (PDC000111)...
# pulling aliquot mapping: breast (PDC000173)...
# pulling aliquot mapping: ucec (PDC000125)...
# pulling aliquot mapping: colorectal_pnnl (PDC000116)...
# pulling aliquot mapping: colorectal_vu (PDC000109)...
# pulling aliquot mapping: pancreatic (PDC000270)...
#  aliquot mappings: 906
#   cancer_type                                       pdc_study_id  \
# 0  colorectal  [PDC000111, b998098f-57b8-11e8-b07a-00a098d917f8]
# 1  colorectal  [PDC000111, b998098f-57b8-11e8-b07a-00a098d917f8]
# 2  colorectal  [PDC000111, b998098f-57b8-11e8-b07a-00a098d917f8]
# 3  colorectal  [PDC000111, b998098f-57b8-11e8-b07a-00a098d917f8]
# 4  colorectal  [PDC000111, b998098f-57b8-11e8-b07a-00a098d917f8]
# 5  colorectal  [PDC000111, b998098f-57b8-11e8-b07a-00a098d917f8]
# 6  colorectal  [PDC000111, b998098f-57b8-11e8-b07a-00a098d917f8]
# 7  colorectal  [PDC000111, b998098f-57b8-11e8-b07a-00a098d917f8]
# 8  colorectal  [PDC000111, b998098f-57b8-11e8-b07a-00a098d917f8]
# 9  colorectal  [PDC000111, b998098f-57b8-11e8-b07a-00a098d917f8]
#
#                                 case_id case_submitter_id  \
# 0  2dfc05ef-63d8-11e8-bcf1-0a2705229b82      TCGA-A6-3807
# 1  2f35a510-63d8-11e8-bcf1-0a2705229b82      TCGA-A6-3808
# 2  3073d082-63d8-11e8-bcf1-0a2705229b82      TCGA-A6-3810
# 3  40f43066-63d8-11e8-bcf1-0a2705229b82      TCGA-AA-3518
# 4  423218ed-63d8-11e8-bcf1-0a2705229b82      TCGA-AA-3525
# 5  4377f550-63d8-11e8-bcf1-0a2705229b82      TCGA-AA-3526
# 6  44b504f0-63d8-11e8-bcf1-0a2705229b82      TCGA-AA-3529
# 7  45f0cbee-63d8-11e8-bcf1-0a2705229b82      TCGA-AA-3531
# 8  472f0ffd-63d8-11e8-bcf1-0a2705229b82      TCGA-AA-3534
# 9  48696542-63d8-11e8-bcf1-0a2705229b82      TCGA-AA-3552
#
#                               sample_id    sample_type  \
# 0  6546c731-641f-11e8-bcf1-0a2705229b82  Primary Tumor
# 1  670a67f3-641f-11e8-bcf1-0a2705229b82  Primary Tumor
# 2  69180d5a-641f-11e8-bcf1-0a2705229b82  Primary Tumor
# 3  80300cbd-641f-11e8-bcf1-0a2705229b82  Primary Tumor
# 4  81c1307f-641f-11e8-bcf1-0a2705229b82  Primary Tumor
# 5  8393dca8-641f-11e8-bcf1-0a2705229b82  Primary Tumor
# 6  85364e69-641f-11e8-bcf1-0a2705229b82  Primary Tumor
# 7  87552140-641f-11e8-bcf1-0a2705229b82  Primary Tumor
# 8  8928dafc-641f-11e8-bcf1-0a2705229b82  Primary Tumor
# 9  8b50022a-641f-11e8-bcf1-0a2705229b82  Primary Tumor
#
#                              aliquot_id         aliquot_submitter_id
# 0  5f565aa6-6428-11e8-bcf1-0a2705229b82  TCGA-A6-3807-01A-22-2150-27
# 1  60aca319-6428-11e8-bcf1-0a2705229b82  TCGA-A6-3808-01A-22-2150-27
# 2  62199412-6428-11e8-bcf1-0a2705229b82  TCGA-A6-3810-01A-22-2150-27
# 3  72d774c3-6428-11e8-bcf1-0a2705229b82  TCGA-AA-3518-01A-11-2150-27
# 4  7425442f-6428-11e8-bcf1-0a2705229b82  TCGA-AA-3525-01A-12-2150-27
# 5  7562afbe-6428-11e8-bcf1-0a2705229b82  TCGA-AA-3526-01A-11-2150-27
# 6  76b2ba5b-6428-11e8-bcf1-0a2705229b82  TCGA-AA-3529-01A-12-2150-27
# 7  77ed565a-6428-11e8-bcf1-0a2705229b82  TCGA-AA-3531-01A-22-2150-27
# 8  7943d515-6428-11e8-bcf1-0a2705229b82  TCGA-AA-3534-01A-22-2150-27
# 9  7a7ff526-6428-11e8-bcf1-0a2705229b82  TCGA-AA-3552-01A-22-2150-27
#   cancer_type                                       pdc_study_id  \
# 0  colorectal  [PDC000111, b998098f-57b8-11e8-b07a-00a098d917f8]
# 1  colorectal  [PDC000111, b998098f-57b8-11e8-b07a-00a098d917f8]
# 2  colorectal  [PDC000111, b998098f-57b8-11e8-b07a-00a098d917f8]
# 3  colorectal  [PDC000111, b998098f-57b8-11e8-b07a-00a098d917f8]
# 4  colorectal  [PDC000111, b998098f-57b8-11e8-b07a-00a098d917f8]
#
#                                 case_id case_submitter_id  \
# 0  2dfc05ef-63d8-11e8-bcf1-0a2705229b82      TCGA-A6-3807
# 1  2f35a510-63d8-11e8-bcf1-0a2705229b82      TCGA-A6-3808
# 2  3073d082-63d8-11e8-bcf1-0a2705229b82      TCGA-A6-3810
# 3  40f43066-63d8-11e8-bcf1-0a2705229b82      TCGA-AA-3518
# 4  423218ed-63d8-11e8-bcf1-0a2705229b82      TCGA-AA-3525
#
#                               sample_id    sample_type  \
# 0  6546c731-641f-11e8-bcf1-0a2705229b82  Primary Tumor
# 1  670a67f3-641f-11e8-bcf1-0a2705229b82  Primary Tumor
# 2  69180d5a-641f-11e8-bcf1-0a2705229b82  Primary Tumor
# 3  80300cbd-641f-11e8-bcf1-0a2705229b82  Primary Tumor
# 4  81c1307f-641f-11e8-bcf1-0a2705229b82  Primary Tumor
#
#                              aliquot_id         aliquot_submitter_id
# 0  5f565aa6-6428-11e8-bcf1-0a2705229b82  TCGA-A6-3807-01A-22-2150-27
# 1  60aca319-6428-11e8-bcf1-0a2705229b82  TCGA-A6-3808-01A-22-2150-27
# 2  62199412-6428-11e8-bcf1-0a2705229b82  TCGA-A6-3810-01A-22-2150-27
# 3  72d774c3-6428-11e8-bcf1-0a2705229b82  TCGA-AA-3518-01A-11-2150-27
# 4  7425442f-6428-11e8-bcf1-0a2705229b82  TCGA-AA-3525-01A-12-2150-27

# %% [markdown]
# Now we can clean up some of the data, enrich with some more helpful derived columns (like 'age' instead of 'days to birth'), and then join the datasets to include all pulled data types in one df. Removing NaNs may need to wait until it becomes more clear which subsets will be most appropriate for analysis in particular modeling scenarios

# %%
merged_data = pd.read_csv("pdc_merged_data.csv")
merged_data.head()

# convert days_to_birth to age in years
merged_data['age_years'] = abs(pd.to_numeric(merged_data['days_to_birth'], errors='coerce')) / 365.25
merged_data.head()
# Out:
#                                 case_id case_submitter_id  \
# 0  2dfc05ef-63d8-11e8-bcf1-0a2705229b82      TCGA-A6-3807
# 1  2f35a510-63d8-11e8-bcf1-0a2705229b82      TCGA-A6-3808
# 2  3073d082-63d8-11e8-bcf1-0a2705229b82      TCGA-A6-3810
# 3  40f43066-63d8-11e8-bcf1-0a2705229b82      TCGA-AA-3518
# 4  423218ed-63d8-11e8-bcf1-0a2705229b82      TCGA-AA-3525
#
#            disease_type primary_site  \
# 0  Colon Adenocarcinoma        Colon
# 1  Colon Adenocarcinoma        Colon
# 2  Colon Adenocarcinoma        Colon
# 3  Colon Adenocarcinoma        Colon
# 4  Colon Adenocarcinoma        Colon
#
#                                         pdc_study_id cancer_type  \
# 0  ['PDC000111', 'b998098f-57b8-11e8-b07a-00a098d...  colorectal
# 1  ['PDC000111', 'b998098f-57b8-11e8-b07a-00a098d...  colorectal
# 2  ['PDC000111', 'b998098f-57b8-11e8-b07a-00a098d...  colorectal
# 3  ['PDC000111', 'b998098f-57b8-11e8-b07a-00a098d...  colorectal
# 4  ['PDC000111', 'b998098f-57b8-11e8-b07a-00a098d...  colorectal
#
#                 ethnicity  gender          race vital_status  days_to_birth  \
# 0  not hispanic or latino  female         white        Alive       -19624.0
# 1  not hispanic or latino    male         white        Alive       -26666.0
# 2  not hispanic or latino    male         white        Alive       -22999.0
# 3            not reported  female  not reported        Alive       -29769.0
# 4            not reported    male  not reported        Alive       -32871.0
#
#    days_to_death  tobacco_smoking_status alcohol_history  years_smoked  \
# 0            NaN                     NaN             NaN           NaN
# 1            NaN                     NaN             NaN           NaN
# 2            NaN                     NaN             NaN           NaN
# 3            NaN                     NaN             NaN           NaN
# 4            NaN                     NaN             NaN           NaN
#
#    pack_years_smoked  age_years
# 0                NaN  53.727584
# 1                NaN  73.007529
# 2                NaN  62.967830
# 3                NaN  81.503080
# 4                NaN  89.995893

# %%
def build_joined_dataset(merged_data, mapping_df, protein_data, cancer_type):
    print(f"\nbuilding joined dataset for {cancer_type}...\n")
    # 'melt' or 'pivot' data so rows are aliquots; this is needed to match the mapping and the case data
    melted_protein = protein_data.T.reset_index()
    melted_protein = melted_protein.rename(columns={'Gene/Aliquot': 'aliquot_submitter_id', 'index': 'aliquot_submitter_id'})
    print(f"transposed protein matrxi shape {melted_protein.shape} "f"(aliquots x genes)")
    print(f" sample aliquot IDs: {melted_protein['aliquot_submitter_id'].head(3).tolist()}")
    
    #filter mapping by cancer type, and remove dupes as specified by matching on aliquot_submitter_id, case_submitter_id, and sample_type- 
    #this should remove any truly duplicate records, but keep cases where one aliquot maps to multiple samples or sample types (eg tumor and normal)
    mapping = mapping_df[mapping_df['cancer_type'] == cancer_type][
        ['aliquot_submitter_id', 'case_submitter_id', 'sample_type']
    ].drop_duplicates()
    print(f"mapping records for {cancer_type}: {len(mapping)}")
    print(f"example mapping aliquot IDs: {mapping['aliquot_submitter_id'].head(3).tolist()}")
    # confirm overlap between protein aliquot IDs and mapping aliquot IDs
    protein_aliquots = set(melted_protein['aliquot_submitter_id'])
    mapping_aliquots = set(mapping['aliquot_submitter_id'])
    overlap = protein_aliquots.intersection(mapping_aliquots)
    print(f"aliquot ID overlap: {len(overlap)} of {len(protein_aliquots)} " f"protein aliquots found in mapping")
    if len(overlap) == 0:
        print(" **** no aliquot ID overlap, nothing to join")
        return None
    # merge expression data with mapping to include match case_submitter_id for joining with clinical data
    merged_exp = melted_protein.merge(mapping, on='aliquot_submitter_id', how='inner')
    print(f"post-mapping shape : {merged_exp.shape}")

    #some clinical datasets use "Patient ID" instead of "case_submitter_id", so rename if needed for the join
    clinical_df = merged_data.copy()
    if 'Patient ID' in clinical_df.columns:
        clinical_df = clinical_df.rename(
            columns={'Patient ID': 'case_submitter_id'})

    #check how many recods match between the datasets for a sanity check
    exp_cases = set(merged_exp['case_submitter_id'])
    clin_cases = set(clinical_df['case_submitter_id'])
    case_overlap = exp_cases.intersection(clin_cases)
    print(f"case id overlap : {len(case_overlap)} " f"of {len(exp_cases)} cases")

    if len(case_overlap) == 0:
        print(" **** no case ID overlap with clinical data")        
        return None
    
    joined = merged_exp.merge(clinical_df, on='case_submitter_id', how='inner')
    print(f" final joined shape:  {joined.shape[0]} rows x {joined.shape[1]} cols")
    return joined

def build_all_cancer_types(merged_data, mapping_df, expression_data):
    all_joined = {}
    for cancer_type, protein_df in expression_data.items():
        result = build_joined_dataset(merged_data, mapping_df, protein_df, cancer_type)
        if result is not None:
            all_joined[cancer_type] = result
    if all_joined:
        combined = pd.concat(all_joined.values(), ignore_index=True)
        print(f"\nCombined dataset: {combined.shape[0]} rows x "
              f"{combined.shape[1]} cols")
        combined.to_csv('pdc_joined_all_cancer_types.csv', index=False)
        return all_joined, combined
    return all_joined, None

# some of the breast cancer set aliquor IDs weren't merging; turns out TCGA ID are formatted slightly differently, 
# but the other IDs are can be extracted from within the string- needed a function ato apply to the mapping table 
# to make everything match up 
def normalize_mapping_id(full_id):
    if full_id.startswith('TCGA-'):
        parts = full_id.split('-')
        #elide the first part (TCGA) and any substrings after the 4th...these are the parts that match the shorter IDs
        if len(parts) >= 4:
            return '-'.join(parts[1:4])
    return full_id

# %%
#pull the prtotein expression data for each study, write out as CSVs for later use if needed, and treturn the dfs also to join with the caase data
def get_protein_expression(study_ids=STUDY_IDS):
    results = {}
    for cancer_type, ids in study_ids.items():
        pdc_id = ids[0]
        print(f"pulling protein expression data: {cancer_type} ({pdc_id})...")

        query = '''
        {quantDataMatrix(pdc_study_id: "%s" data_type: "log2_ratio" acceptDUA: true)}
        ''' % pdc_id
        data = pdc_graphql_query(query)
        if data is None:
            continue
        matrix = data['data']['quantDataMatrix']
        if not matrix:
            print(f"  no data returned for {pdc_id}")
            continue
        prot_df = pd.DataFrame(matrix[1:], columns=matrix[0])
        prot_df = df.set_index('Gene/Aliquot')

        #some column names are in the format "study_id:aliquot_id", so split on colon and take the second part to get just the aliquot ID; if no colon, keep as is
        original_cols = list(df.columns) 
        cleaned_cols = [col.split(':')[1] if ':' in col else col for col in original_cols]
        prot_df.columns = cleaned_cols 
        prot_df = prot_df.sort_index(axis=1)
        #the protein contents data came through as strings, but it should be floats # TODO- double check other demographic and exposure data for mistyped numerical values 
        for col in prot_df.columns:
            prot_df[col] = pd.to_numeric(prot_df[col], errors='coerce')
        
        results[cancer_type] = prot_df
        prot_df.to_csv(f'pdc_protein_expression_{cancer_type}.csv')
    return results

# %%
protein_data = get_protein_expression()

# %%
mapping_df = pd.read_csv('pdc_aliquot_mapping.csv')
#breast cancer data IDs are TCGA format, so need to normalize them using the above function before the join
mapping_df['aliquot_submitter_id'] = mapping_df.apply(lambda row: normalize_mapping_id(row['aliquot_submitter_id']) 
                                                      if row['cancer_type'] == 'breast' else row['aliquot_submitter_id'], axis=1)

#initial join runs showed colorectal had more rows than expected; traced back to dupliated case_submitter_id values in the 
#merged data, so drop those dupes before the join
merged_data = merged_data.drop_duplicates(subset=['case_submitter_id'])
all_joined, combined = build_all_cancer_types(merged_data, mapping_df, protein_data )
# Out:
# building joined dataset for breast...
#
#   transposed protein matrxi shape (111, 10626) (aliquots x genes)
#   sample aliquot IDs: ['263d3f-I', 'A2-A0CM-01A', 'A2-A0D0-01A']
#   Mapping records for breast: 109
#   Sample mapping aliquot IDs: ['BH-A18U-01A', 'BH-A0C0-01A', 'A8-A08Z-01A']
#   Sample types available: ['Primary Tumor', 'Not Reported', 'Normal Adjacent Tissue']
#   aliquot ID overlap: 104 of 111 protein aliquots found in mapping
# post-mapping shape : (104, 10628)
# case ID overlap : 104 of 104 cases
#   Final joined shape: 104 rows x 10644 cols
#
# building joined dataset for ucec...
#
#   transposed protein matrxi shape (149, 10769) (aliquots x genes)
#   sample aliquot IDs: ['CPT0000730011', 'CPT0000980012', 'CPT0001140003']
#   Mapping records for ucec: 154
#   Sample mapping aliquot IDs: ['CPT0080890001', 'CPT0080880003', 'CPT0000980012']
#   Sample types available: ['Solid Tissue Normal', 'Primary Tumor', 'Not Reported']
#   aliquot ID overlap: 149 of 149 protein aliquots found in mapping
# post-mapping shape : (149, 10771)
# case ID overlap : 119 of 119 cases
#   Final joined shape: 149 rows x 10787 cols
#
# building joined dataset for colorectal_pnnl...
#
#   transposed protein matrxi shape (198, 7419) (aliquots x genes)
#   sample aliquot IDs: ['0065bfd9-e1b9-43a8-9379-9658ba_D3', '019cd0c0-733d-4b25-90e3-d54ce0_D2', '01d1ffca-4235-4dfe-bf62-56f71d_D3']
#   Mapping records for colorectal_pnnl: 198
#   Sample mapping aliquot IDs: ['8cc7e656-0152-4359-8566-0581c3', '5347d2ce-df0c-4d81-a3e2-22db11_D2', '5c70e654-583c-4dd3-ad42-0d9b39_D2']
#   Sample types available: ['Primary Tumor', 'Solid Tissue Normal', 'Not Reported']
#   aliquot ID overlap: 197 of 198 protein aliquots found in mapping
# post-mapping shape : (197, 7421)
# case ID overlap : 101 of 101 cases
#   Final joined shape: 197 rows x 7437 cols
#
# building joined dataset for pancreatic...
#
#   transposed protein matrxi shape (230, 10117) (aliquots x genes)
#   sample aliquot IDs: ['C3L-00189-04', 'C3L-00401-04', 'C3L-03632-04']
#   Mapping records for pancreatic: 250
#   Sample mapping aliquot IDs: ['CPT0186050004', 'CPT0186040004', 'CPT0208690004']
#   Sample types available: ['Solid Tissue Normal', 'Primary Tumor', 'Not Reported', 'Cell Lines', 'Tumor']
#   aliquot ID overlap: 228 of 230 protein aliquots found in mapping
# post-mapping shape : (228, 10119)
# case ID overlap : 160 of 160 cases
#   Final joined shape: 228 rows x 10135 cols
#
# Combined dataset: 678 rows x 12172 cols
